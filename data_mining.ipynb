# %%
from collections import Counter
from tqdm import tqdm
import numpy as np
import re

# %%
with open('data/instance_types_transitive_wkd_uris_en.ttl', 'r', encoding='utf-8') as f:
    text1 = f.read()

# %%
triplets_instance = text1.split('\n')[1:-2]

# %%
q_id = set()
r_q = r'dbpedia.org/resource/(.*?)>'

for triplet in triplets_instance:
    if '/Person>' in triplet:
        q_id.add(re.search(r_q,triplet).group(1))
        
q_id = np.array(list(q_id))

# %%
del(triplets_instance)
del(text1)

# %%
with open('data/mappingbased_literals_wkd_uris_en.ttl', 'r', encoding='utf-8') as f:
    text2 = f.read()

# %%
triplets_names = text2.split('\n')[1:-2]

# %%
r_names = r'/name> "([A-Za-z\.\-\' ]*)"@en'
r_q = r'dbpedia.org/resource/(.*?)>'
q2name = dict()
for triplet in tqdm(triplets_names):
    name = re.search(r_names, triplet)
    q_group = re.search(r_q,triplet)
    
    if name is not None:
        q2name[q_group.group(1)] = name.group(1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10841856/10841856 [00:49<00:00, 218567.93it/s]

# %%
del(text2)
del(triplets_names)

# %%
person_names = []
for group in tqdm(q_id):
    try:
        person_names.append(q2name[group])
        q2name.pop(group)
    except:
        pass

non_person_names = q2name.values()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 917509/917509 [00:02<00:00, 454001.42it/s]

# %%
print(len(set(person_names)))
Counter(person_names).most_common()
# Out:
# 645405
# [('unknown', 171),
#  ('Saint', 51),
#  ('Governor', 49),
#  ('John Smith', 48),
#  ('Blessed', 38),
#  ('John Williams', 31),
#  ('William Smith', 31),
#  ('John Brown', 30),
#  ('William', 29),
#  ('Venerable', 29),
#  ('John Taylor', 27),
#  ('Unknown', 27),
#  ('James Smith', 26),
#  ('George Smith', 26),
#  ('David Jones', 26),
#  ('John Wilson', 26),
#  ('David Smith', 25),
#  ('John Campbell', 25),
#  ('Tom Smith', 24),
#  ('MBE', 24),
#  ('OBE', 23),
#  ('Charles', 23),
#  ('John White', 23),
#  ('John Ryan', 22),
#  ('John Davis', 22),
#  ('John Anderson', 22),
#  ('John Scott', 21),
#  ('Robert Smith', 21),
#  ('Paul Smith', 21),
#  ('Juninho', 21),
#  ('Steve Smith', 20),
#  ('John Roberts', 19),
#  ('John', 19),
#  ('Fred Smith', 19),
#  ('Robert Brown', 19),
#  ('John Evans', 19),
#  ('John Martin', 19),
#  ('John Moore', 19),
#  ('Mike Smith', 18),
#  ('Richard Smith', 18),
#  ('thumb', 18),
#  ('Serginho', 18),
#  ('John Murphy', 18),
#  ('John Walker', 18),
#  ('John II', 18),
#  ('Louis', 18),
#  ('Michael Smith', 18),
#  ('Fernando', 18),
#  ('Ali', 17),
#  ('William Brown', 17),
#  ('John Watson', 17),
#  ('John Young', 17),
#  ('James Stewart', 17),
#  ('Harry Smith', 17),
#  ('T.O.S.F.', 17),
#  ('Roberto', 17),
#  ('Paul Williams', 16),
#  ('William Jones', 16),
#  ('John Allen', 16),
#  ('John Thompson', 16),
#  ('John Bell', 16),
#  ('John Sullivan', 16),
#  ('David Wilson', 16),
#  ('John Hill', 16),
#  ('William Miller', 16),
#  ('Greg Smith', 16),
#  ('Mark Williams', 16),
#  ('Servant of God', 16),
#  ('John Fraser', 16),
#  ('Right Reverend', 16),
#  ('Mehmed', 16),
#  ('William Wilson', 16),
#  ('Mark Smith', 16),
#  ('Marquinhos', 16),
#  ('Paul Johnson', 15),
#  ('Jim Brown', 15),
#  ('David Williams', 15),
#  ('The Earl of Kinnoull', 15),
#  ('Mark Jones', 15),
#  ('O.P.', 15),
#  ('John Hayes', 15),
#  ('George Brown', 15),
#  ('John Morris', 15),
#  ('Arthur Smith', 15),
#  ('John Kennedy', 15),
#  ('Henry I', 15),
#  ('Chris Smith', 15),
#  ('George Williams', 15),
#  ('John Hamilton', 15),
#  ('Richard Jones', 15),
#  ('James Wilson', 15),
#  ('John Clark', 15),
#  ('John Kelly', 15),
#  ('Imran Khan', 15),
#  ('Steve Williams', 14),
#  ('Alexander', 14),
#  ('Peter Williams', 14),
#  ('John Miller', 14),
#  ('Frank Williams', 14),
#  ('George Taylor', 14),
#  ('John Harris', 14),
#  ('Robert Wilson', 14),
#  ('John Marshall', 14),
#  ("John O'Brien", 14),
#  ('United States Air Force', 14),
#  ('O.F.M. Cap.', 14),
#  ('Jeff Smith', 14),
#  ('Daniel', 14),
#  ('John Ward', 14),
#  ('The Earl of Erroll', 14),
#  ('John Murray', 14),
#  ('John Doyle', 14),
#  ('David Johnson', 14),
#  ('John Black', 14),
#  ('Brian Johnson', 13),
#  ('Jack Smith', 13),
#  ('James Young', 13),
#  ('John Jackson', 13),
#  ('Bill Anderson', 13),
#  ('William Watson', 13),
#  ('David Lee', 13),
#  ('Mike Jones', 13),
#  ('Princess Marie', 13),
#  ('Mark Davis', 13),
#  ('John Simpson', 13),
#  ('Steve Jones', 13),
#  ('John King', 13),
#  ('Paul Jones', 13),
#  ('Henry II', 13),
#  ('Samuel', 13),
#  ('Robert Taylor', 13),
#  ('John Edwards', 13),
#  ('John I', 13),
#  ('Frank Smith', 13),
#  ("John O'Neill", 13),
#  ('Frederick I', 12),
#  ('Henrique', 12),
#  ('Peter', 12),
#  ('Alex Smith', 12),
#  ('John Thomas', 12),
#  ('Jimmy Jones', 12),
#  ('John Lewis', 12),
#  ('George Wilson', 12),
#  ('John Armstrong', 12),
#  ('Mark Johnson', 12),
#  ('Matt Williams', 12),
#  ('Michael Murphy', 12),
#  ('O.S.A.', 12),
#  ('William Williams', 12),
#  ('John Ross', 12),
#  ('Fred Jones', 12),
#  ('John Howard', 12),
#  ('John Robertson', 12),
#  ('Mark Robinson', 12),
#  ('William I', 12),
#  ('George Anderson', 12),
#  ('Toni', 12),
#  ('Charles Thomas', 12),
#  ('David Taylor', 12),
#  ('President', 12),
#  ('James Moore', 12),
#  ('George', 12),
#  ('James Walker', 12),
#  ('Tony Smith', 12),
#  ('James Martin', 12),
#  ('David Young', 12),
#  ('The Duke of Norfolk', 12),
#  ('The Lord Byron', 12),
#  ('William Hamilton', 12),
#  ('John Hughes', 12),
#  ('John Jones', 12),
#  ('Jason Smith', 12),
#  ('Princess Louise', 12),
#  ('John Davies', 12),
#  ('Aftab Ahmed', 12),
#  ('John James', 11),
#  ('John Wood', 11),
#  ('Alan Smith', 11),
#  ('John Pearson', 11),
#  ('John Grant', 11),
#  ('William Moore', 11),
#  ('Richard Williams', 11),
#  ('David Walker', 11),
#  ('John Russell', 11),
#  ('John Johnson', 11),
#  ('Gabriel', 11),
#  ('John Henderson', 11),
#  ('John Gray', 11),
#  ('David Hall', 11),
#  ('Peter Smith', 11),
#  ('Paul Taylor', 11),
#  ('John Stewart', 11),
#  ('George Miller', 11),
#  ('David Thompson', 11),
#  ('James Brown', 11),
#  ('Bill Brown', 11),
#  ('Jimmy Smith', 11),
#  ('Louis I', 11),
#  ('David Brown', 11),
#  ('Princess Alexandra', 11),
#  ('Marcelo', 11),
#  ('Peter Jones', 11),
#  ('Bob Smith', 11),
#  ('Ijaz Ahmed', 11),
#  ('Frederick II', 11),
#  ('John Cameron', 11),
#  ('David Hill', 11),
#  ('Jim Smith', 11),
#  ('James King', 11),
#  ('Bill Smith', 11),
#  ('Tommy Thompson', 11),
#  ('John Payne', 11),
#  ('Brian Murphy', 11),
#  ('John Richardson', 11),
#  ('John Bailey', 11),
#  ('John Robinson', 11),
#  ('James Miller', 11),
#  ('Bill Jones', 11),
#  ('Michael Taylor', 11),
#  ('Francis', 11),
#  ('George Jackson', 11),
#  ("Kevin O'Brien", 11),
#  ('David Harris', 11),
#  ('Mohammad Naeem', 11),
#  ('Frank Murphy', 11),
#  ('George Thompson', 11),
#  ('David Thomas', 11),
#  ('O.F.M.', 11),
#  ('John Walsh', 11),
#  ('David Lloyd', 11),
#  ('Mike Brown', 11),
#  ('William Taylor', 11),
#  ('Jimmy Kelly', 10),
#  ('Ben Wilson', 10),
#  ('Paul Miller', 10),
#  ('George Jones', 10),
#  ('Matt Smith', 10),
#  ('John Carter', 10),
#  ('Gordon Brown', 10),
#  ('Peter Brown', 10),
#  ('Jack White', 10),
#  ('Scott Taylor', 10),
#  ('David Evans', 10),
#  ('Richard Wilson', 10),
#  ('Jack Ryan', 10),
#  ('Fabinho', 10),
#  ('Bill Thomas', 10),
#  ('John Fitzgerald', 10),
#  ('Tiago', 10),
#  ('James Campbell', 10),
#  ('Tony Brown', 10),
#  ('Charlie Brown', 10),
#  ('Ian Stewart', 10),
#  ('Willie Smith', 10),
#  ('David James', 10),
#  ('Bill Johnson', 10),
#  ('Jim Clark', 10),
#  ('Paul Kelly', 10),
#  ('Tom Williams', 10),
#  ('Tom Davis', 10),
#  ('Ian Smith', 10),
#  ('The Duke of Devonshire', 10),
#  ('John Mason', 10),
#  ('Alberto', 10),
#  ('Tom Johnson', 10),
#  ('Jim Wilson', 10),
#  ('Prince Alexander', 10),
#  ('John Wilkinson', 10),
#  ('Tom Hughes', 10),
#  ('Joseph Smith', 10),
#  ('Robert White', 10),
#  ('Mike Williams', 10),
#  ('Paulinho', 10),
#  ('The Duke of Beaufort', 10),
#  ('Gary Smith', 10),
#  ('Chris Turner', 10),
#  ('Jorginho', 10),
#  ('Chris Jones', 10),
#  ('Andrew Wilson', 10),
#  ('William Johnson', 10),
#  ('Frank Johnson', 10),
#  ('John Hall', 10),
#  ('James Grant', 10),
#  ('Colin Campbell', 10),
#  ('Charles I', 10),
#  ('John Baker', 10),
#  ('Robert Scott', 10),
#  ('John Daly', 10),
#  ('William Robinson', 10),
#  ('Gareth Williams', 10),
#  ('Ray Williams', 10),
#  ('John McCarthy', 10),
#  ('Thomas Brown', 10),
#  ('Mohammad Irfan', 10),
#  ('Robert Morris', 10),
#  ('Michael Johnson', 10),
#  ('Brian Kelly', 10),
#  ('Ron Smith', 10),
#  ('David Jackson', 10),
#  ('Prince Frederick', 10),
#  ('William Thomas', 10),
#  ('Diego', 10),
#  ('Tom Wilson', 10),
#  ('Brian Taylor', 10),
#  ('Jason Williams', 10),
#  ('George Johnson', 10),
#  ('Maria', 10),
#  ('Philip I', 10),
#  ('David Campbell', 10),
#  ('William Russell', 10),
#  ('John Collins', 10),
#  ('John Spencer', 10),
#  ('Jefferson', 10),
#  ('John Morgan', 10),
#  ('Sandro', 10),
#  ('Peter Murphy', 10),
#  ('Leandro', 10),
#  ('John Harvey', 10),
#  ('Bobby Jones', 10),
#  ('Peter Hall', 10),
#  ('John Phillips', 9),
#  ('Brian Hill', 9),
#  ('William Anderson', 9),
#  ('Rafinha', 9),
#  ('John Barrett', 9),
#  ('Mark Taylor', 9),
#  ('John Chapman', 9),
#  ('Keith Smith', 9),
#  ('Robert', 9),
#  ('Michael Jackson', 9),
#  ('Fred Taylor', 9),
#  ('Michael Walsh', 9),
#  ('Roger', 9),
#  ('George Green', 9),
#  ('Michael Collins', 9),
#  ('Mike Kelly', 9),
#  ('Charles Jones', 9),
#  ('Marcos', 9),
#  ('William Morris', 9),
#  ('Matt Jones', 9),
#  ('Felipe', 9),
#  ('Eduardo', 9),
#  ('Jim Stewart', 9),
#  ('Carlos', 9),
#  ('The Duke of Marlborough', 9),
#  ('Robert Walker', 9),
#  ('Ben Jones', 9),
#  ('Mark Thompson', 9),
#  ('Alan Brown', 9),
#  ('George Scott', 9),
#  ('Jim Miller', 9),
#  ('Alex', 9),
#  ('Andy Williams', 9),
#  ('John III', 9),
#  ('Ahmed', 9),
#  ('The Duke of Northumberland', 9),
#  ('John Warner', 9),
#  ('Brian Wilson', 9),
#  ('John Lee', 9),
#  ('David White', 9),
#  ('Edu', 9),
#  ('Frederick', 9),
#  ('Stephen', 9),
#  ('Andrew Miller', 9),
#  ('John Adams', 9),
#  ('Michael', 9),
#  ('John Hart', 9),
#  ('Kevin Smith', 9),
#  ('Constance', 9),
#  ('George Stewart', 9),
#  ('Mark Lee', 9),
#  ('David Martin', 9),
#  ('Thomas Smith', 9),
#  ('Gareth Evans', 9),
#  ('William Morgan', 9),
#  ('Bob Brown', 9),
#  ('Robert Williams', 9),
#  ('Guilherme', 9),
#  ('Peter King', 9),
#  ('Christian', 9),
#  ('Tony Martin', 9),
#  ('John Price', 9),
#  ('Harry Wilson', 9),
#  ('John Hopkins', 9),
#  ('James Murray', 9),
#  ('Jim Davis', 9),
#  ('Robert Anderson', 9),
#  ('William Thompson', 9),
#  ('David Edwards', 9),
#  ('Willie Brown', 9),
#  ('Danny Williams', 9),
#  ('James Allan', 9),
#  ('James Johnston', 9),
#  ('David Murray', 9),
#  ('Mike Davis', 9),
#  ('John Ellis', 9),
#  ('Jim Williams', 9),
#  ('Thomas Ryan', 9),
#  ('John Cooper', 9),
#  ('Tommy Smith', 9),
#  ('John Wright', 9),
#  ('Fred Williams', 9),
#  ('George Walker', 9),
#  ('John Green', 9),
#  ('James Reid', 9),
#  ('The Most Reverend', 9),
#  ('John Rogers', 9),
#  ('Chris Wood', 9),
#  ('Paul Martin', 9),
#  ('Jimmy Walsh', 9),
#  ('Paul Wilson', 9),
#  ('Dani', 9),
#  ('Mustafa', 9),
#  ('David Miller', 9),
#  ('Mike Johnson', 9),
#  ('Joe Kelly', 9),
#  ('Gordon Smith', 9),
#  ('The Earl of Bessborough', 9),
#  ('Patrick Murphy', 9),
#  ('William Walker', 9),
#  ('Scott Brown', 9),
#  ('Leonardo', 9),
#  ('John Ford', 9),
#  ('Andy Smith', 9),
#  ('John George', 8),
#  ('Bill Wilson', 8),
#  ('James Allen', 8),
#  ('Juanito', 8),
#  ('Thomas Miller', 8),
#  ('Steve Brown', 8),
#  ('Jean', 8),
#  ('John Cunningham', 8),
#  ('John Palmer', 8),
#  ('Henry', 8),
#  ('Mike Green', 8),
#  ('Isabella', 8),
#  ('Lucas', 8),
#  ('The Duke of Wellington', 8),
#  ('Charlotte', 8),
#  ('The Duke of Rutland', 8),
#  ('William Scott', 8),
#  ('William Stewart', 8),
#  ('George Harris', 8),
#  ('Charles Taylor', 8),
#  ('Charles II', 8),
#  ('James Cowan', 8),
#  ('David Morris', 8),
#  ('David Lewis', 8),
#  ('Princess Elisabeth', 8),
#  ('Henry III', 8),
#  ('Steve Johnson', 8),
#  ('James White', 8),
#  ('James Shaw', 8),
#  ('James Jones', 8),
#  ('Anderson', 8),
#  ('Chris Williams', 8),
#  ('John Hunter', 8),
#  ('David Davies', 8),
#  ('John Burke', 8),
#  ('The Hammer', 8),
#  ('Paul Brown', 8),
#  ('Rafael', 8),
#  ('William Davies', 8),
#  ('William Douglas', 8),
#  ('Don Cameron', 8),
#  ('Ivan Ivanov', 8),
#  ('Tony Evans', 8),
#  ('The Predator', 8),
#  ('Mark Wright', 8),
#  ('John Allan', 8),
#  ('Tom Watson', 8),
#  ('Charles III', 8),
#  ('Junior', 8),
#  ('John Burns', 8),
#  ('Mark Wilson', 8),
#  ('Luizinho', 8),
#  ('John Gardner', 8),
#  ('William Ward', 8),
#  ('George Carter', 8),
#  ('Nathan Smith', 8),
#  ('Bill Cunningham', 8),
#  ('Stephen Jones', 8),
#  ('John Patterson', 8),
#  ('Peter Ryan', 8),
#  ('William Graham', 8),
#  ('Jeff Jones', 8),
#  ('The Earl of Westmorland', 8),
#  ('William Hill', 8),
#  ('William Robertson', 8),
#  ('David Bell', 8),
#  ('Scott Smith', 8),
#  ('Mark Evans', 8),
#  ('Tommy Taylor', 8),
#  ('Paul Robinson', 8),
#  ('James Thompson', 8),
#  ('Chris Kelly', 8),
#  ('William Roberts', 8),
#  ('Bill White', 8),
#  ('John Parker', 8),
#  ('Tommy Walker', 8),
#  ('Renan', 8),
#  ('Bill Lee', 8),
#  ('William James', 8),
#  ('John Freeman', 8),
#  ("Michael O'Brien", 8),
#  ('Dennis Smith', 8),
#  ('John Alexander', 8),
#  ('Robert Jones', 8),
#  ('Princess Charlotte', 8),
#  ('Gonzalo', 8),
#  ('Nando', 8),
#  ('Diogo', 8),
#  ('Bill Walker', 8),
#  ('John McGrath', 8),
#  ('William King', 8),
#  ('Henry IV', 8),
#  ('William Richardson', 8),
#  ('George Turner', 8),
#  ('Willie Anderson', 8),
#  ('Thiago', 8),
#  ('John Farrell', 8),
#  ('William Allen', 8),
#  ('Ken Jones', 8),
#  ('Brian Smith', 8),
#  ('John Harrison', 8),
#  ('Princess Augusta', 8),
#  ('Adriano', 8),
#  ('Ron Johnson', 8),
#  ('Brad Smith', 8),
#  ('James Hall', 8),
#  ('John Ferguson', 8),
#  ('Harry Allen', 8),
#  ('Albert II', 8),
#  ('George Watson', 8),
#  ('Peter Wright', 8),
#  ('Ian Taylor', 8),
#  ('John Jenkins', 8),
#  ("Mike O'Brien", 8),
#  ('John Turner', 8),
#  ('Jonathan Smith', 8),
#  ('thumbnail', 8),
#  ('Danny Murphy', 8),
#  ('The Beast', 8),
#  ('Peter Marshall', 8),
#  ('Ted Smith', 8),
#  ('Mark Hughes', 8),
#  ('James Robinson', 8),
#  ('Andrew Brown', 8),
#  ('John Mitchell', 8),
#  ('William Parker', 8),
#  ('Robert Bell', 8),
#  ('Kevin Brown', 8),
#  ('John Ball', 8),
#  ('Dave Roberts', 8),
#  ('Richard Johnson', 8),
#  ('John Lyons', 8),
#  ('Dave Smith', 8),
#  ('Michael Brown', 8),
#  ('Thomas Davis', 8),
#  ('David Stewart', 8),
#  ('Paul Ryan', 8),
#  ('David Watson', 8),
#  ('William Adams', 8),
#  ('Marinho', 8),
#  ('John Middleton', 8),
#  ('William II', 8),
#  ('Peter I', 8),
#  ('Will Smith', 8),
#  ('William Martin', 8),
#  ('Abdul Aziz', 8),
#  ('Chris Carter', 8),
#  ('John Carroll', 8),
#  ('John Holt', 8),
#  ('William Young', 8),
#  ('Bill Harris', 8),
#  ('Jaime', 8),
#  ("Jim O'Brien", 8),
#  ('David Butler', 8),
#  ('Ben Johnson', 8),
#  ('Tony Jones', 7),
#  ('Thomas Young', 7),
#  ('Michael Harris', 7),
#  ('Michael Thomas', 7),
#  ('Charles Williams', 7),
#  ('John Henry', 7),
#  ('John Cooke', 7),
#  ('John Morton', 7),
#  ('David Price', 7),
#  ('Robert Chambers', 7),
#  ('John Vaughan', 7),
#  ('Charles Martin', 7),
#  ('George Graham', 7),
#  ('Peter Jackson', 7),
#  ('John Gilbert', 7),
#  ('Mick Murphy', 7),
#  ('John Butler', 7),
#  ('Rhys Williams', 7),
#  ('John Wallace', 7),
#  ('Henry Williams', 7),
#  ('Eric Anderson', 7),
#  ('Joachim Murat', 7),
#  ('George Shaw', 7),
#  ('Pedro', 7),
#  ('James Green', 7),
#  ('General', 7),
#  ('Tom Kennedy', 7),
#  ('Thomas', 7),
#  ('Robert Harris', 7),
#  ('John Clarke', 7),
#  ('Zhang Li', 7),
#  ('Most Reverend', 7),
#  ('Darren Smith', 7),
#  ('Ben Smith', 7),
#  ('David Kennedy', 7),
#  ('David Bradley', 7),
#  ('Borja', 7),
#  ('David Johnston', 7),
#  ('David Robinson', 7),
#  ('Ray Smith', 7),
#  ('Tom Hayes', 7),
#  ('David Jenkins', 7),
#  ('Jim McDonald', 7),
#  ('Shakeel Ahmed', 7),
#  ('Imtiaz Ahmed', 7),
#  ('Richard Taylor', 7),
#  ('Jack Davis', 7),
#  ('William Gordon', 7),
#  ('Princess Sophie', 7),
#  ('John Archer', 7),
#  ('The Duke of Portland', 7),
#  ('Jack Green', 7),
#  ('James Douglas', 7),
#  ('The Right Reverend', 7),
#  ('John Nelson', 7),
#  ('Robert Hunter', 7),
#  ('David Parker', 7),
#  ('Bill Taylor', 7),
#  ('Henry Smith', 7),
#  ('William Holmes', 7),
#  ('James Davies', 7),
#  ('Prince Christian', 7),
#  ('Thomas Jefferson', 7),
#  ('John McLaughlin', 7),
#  ('Barry Jones', 7),
#  ('Pete Smith', 7),
#  ('Peter Young', 7),
#  ('James Gordon', 7),
#  ('Michael Thompson', 7),
#  ('Billy Williams', 7),
#  ('Marquinho', 7),
#  ('Mark Baker', 7),
#  ('Jim Jones', 7),
#  ("Dan O'Brien", 7),
#  ('Wulfsige', 7),
#  ('Peter White', 7),
#  ('James Duncan', 7),
#  ('Luciano', 7),
#  ('Steve Thompson', 7),
#  ('The Earl of Pembroke', 7),
#  ('Paul Stewart', 7),
#  ('David Robertson', 7),
#  ('Jack King', 7),
#  ('Luan', 7),
#  ('Craig Smith', 7),
#  ('James Taylor', 7),
#  ('Michael Ryan', 7),
#  ('The Rock', 7),
#  ('Arthur Turner', 7),
#  ('Terry Jones', 7),
#  ('Bill Miller', 7),
#  ('William Bailey', 7),
#  ('Michael Scott', 7),
#  ("Jack O'Brien", 7),
#  ('David Bennett', 7),
#  ('Bob Evans', 7),
#  ('William Hutchinson', 7),
#  ('Kiko', 7),
#  ('George Evans', 7),
#  ('John Coleman', 7),
#  ('John Kerr', 7),
#  ('Mike Walker', 7),
#  ("John O'Connor", 7),
#  ('Jim White', 7),
#  ('Robert Campbell', 7),
#  ('George King', 7),
#  ('Mohammad Yousuf', 7),
#  ('O.S.M.', 7),
#  ('Simon', 7),
#  ('James Jackson', 7),
#  ('Adam Smith', 7),
#  ('Kevin Moore', 7),
#  ('Michael Coleman', 7),
#  ('Pedro II', 7),
#  ('Paul Young', 7),
#  ('William Price', 7),
#  ('Abdul Rahman', 7),
#  ('Samuel Johnson', 7),
#  ('George Murray', 7),
#  ('Tony Johnson', 7),
#  ('Scott Miller', 7),
#  ('John Forbes', 7),
#  ('Peter Taylor', 7),
#  ('Manu', 7),
#  ('Samuel Smith', 7),
#  ('Larry Smith', 7),
#  ('Tom Murphy', 7),
#  ("Paul O'Neill", 7),
#  ('Peter Campbell', 7),
#  ('Jack Wilson', 7),
#  ('Jason White', 7),
#  ('Peter Robinson', 7),
#  ('Ken Smith', 7),
#  ('Tom Evans', 7),
#  ('Tom Holland', 7),
#  ('Gary Wilson', 7),
#  ('Chris Collins', 7),
#  ('Bob Wilson', 7),
#  ('Robert Wright', 7),
#  ('Charles Anderson', 7),
#  ('Chris Walker', 7),
#  ('Julinho', 7),
#  ('Charlie Wilson', 7),
#  ('Harry Taylor', 7),
#  ('Jim Kelly', 7),
#  ('Michael Wilson', 7),
#  ('Jim Sullivan', 7),
#  ('Peter Wilson', 7),
#  ('Sam Williams', 7),
#  ('John Ritchie', 7),
#  ('David Anderson', 7),
#  ('Robert King', 7),
#  ('George Neville', 7),
#  ('Joe Johnson', 7),
#  ('Bill Davis', 7),
#  ('Jim Marshall', 7),
#  ('Robert Bruce', 7),
#  ('James Ryan', 7),
#  ('John Brooks', 7),
#  ('Ferdinand I', 7),
#  ('Steve White', 7),
#  ('Michael Evans', 7),
#  ('Wilhelm', 7),
#  ('Bobby Brown', 7),
#  ('Mark Wood', 7),
#  ('Barry Evans', 7),
#  ('Jack Jones', 7),
#  ('Patrick Kelly', 7),
#  ('James Kelly', 7),
#  ('George Wright', 7),
#  ('Gary Williams', 7),
#  ('Frank Wilson', 7),
#  ('Frank Thomas', 7),
#  ('George Lewis', 7),
#  ('Robert Gray', 7),
#  ('James Adams', 7),
#  ("Michael O'Connor", 7),
#  ('Robert Ferguson', 7),
#  ('John West', 7),
#  ('Christopher Williams', 7),
#  ('Doug Smith', 7),
#  ('Alexis', 7),
#  ('John Berry', 7),
#  ('Yasser Corona', 7),
#  ('James Roberts', 7),
#  ('Chris Brown', 7),
#  ('Ian Wilson', 7),
#  ('David Clarke', 7),
#  ('Roy Smith', 7),
#  ('Elisabeth', 7),
#  ('Richard Hill', 7),
#  ('Tom Brown', 7),
#  ('Bill Evans', 7),
#  ('Edgar', 7),
#  ('William Harris', 7),
#  ('Michael Adams', 7),
#  ('The Marquess of Salisbury', 7),
#  ('Eddie Phillips', 7),
#  ('Wellington', 7),
#  ('Michael White', 7),
#  ('Don Wilson', 7),
#  ('Prince Henry', 7),
#  ('Patrick Kennedy', 7),
#  ('Mike Jackson', 7),
#  ('Robert Thompson', 7),
#  ('Daniel Smith', 7),
#  ('Margaret', 7),
#  ('Tom Sullivan', 7),
#  ('Bill Thompson', 7),
#  ('David Collins', 7),
#  ('George Gibson', 7),
#  ('William Wright', 7),
#  ('Al Smith', 7),
#  ('Gary Jones', 7),
#  ('Zhang Lei', 7),
#  ('George Adams', 7),
#  ('Larry Miller', 7),
#  ('Robert Gordon', 7),
#  ('Peter II', 7),
#  ('Tim Ryan', 7),
#  ('John Duffy', 7),
#  ('William Henderson', 7),
#  ('Jack Taylor', 7),
#  ('Steve Davis', 7),
#  ('William White', 7),
#  ('Frank Taylor', 7),
#  ('Andrew Scott', 7),
#  ("Tom O'Brien", 7),
#  ('James Hamilton', 7),
#  ('Keith Miller', 7),
#  ('Alan Williams', 7),
#  ('Roy Williams', 7),
#  ('John Fox', 7),
#  ('Louis II', 7),
#  ('Kevin James', 7),
#  ('Peter Doyle', 7),
#  ('David Russell', 7),
#  ('Nick Smith', 7),
#  ('John Hope', 7),
#  ('Mike Edwards', 7),
#  ('Thomas Jones', 7),
#  ('Mark Lewis', 7),
#  ('David Nelson', 7),
#  ('Paul Quinn', 7),
#  ('John Reynolds', 7),
#  ('Chris Johnson', 7),
#  ('Catherine', 7),
#  ('George Young', 7),
#  ('Matt Taylor', 7),
#  ('James Johnson', 7),
#  ('The Earl of Carnarvon', 7),
#  ('Robert I', 7),
#  ('William Murphy', 7),
#  ('Alexandre', 7),
#  ('Bob Allen', 7),
#  ('Pat Murphy', 7),
#  ('Eric Johnson', 7),
#  ('Mike Miller', 7),
#  ('Bill Scott', 7),
#  ('Emerson', 7),
#  ('Jim Lewis', 7),
#  ('William Clarke', 7),
#  ('Richard Moore', 7),
#  ('O.F.S.', 7),
#  ('Tom Jones', 7),
#  ('John Brady', 7),
#  ('John Boyd', 7),
#  ('William Campbell', 7),
#  ('Bob Johnson', 7),
#  ('Marie', 7),
#  ('Mark Andrews', 6),
#  ('Brian Jackson', 6),
#  ('Frank Thompson', 6),
#  ('Ibrahim', 6),
#  ('Gordon Jones', 6),
#  ('Craig Wilson', 6),
#  ('David Rees', 6),
#  ('Juanma', 6),
#  ('Prince George', 6),
#  ('Ziguy Badibanga', 6),
#  ('John Leslie', 6),
#  ('James Burke', 6),
#  ('Melody', 6),
#  ('Dean Smith', 6),
#  ('Bruce Smith', 6),
#  ('Lee Rogers', 6),
#  ('Daniel Jones', 6),
#  ('Andy Lee', 6),
#  ('Daniel James', 6),
#  ('Michael Young', 6),
#  ('Krishna', 6),
#  ('Michael McDonald', 6),
#  ('David Wright', 6),
#  ('Steve Moore', 6),
#  ('Dan Kelly', 6),
#  ('Bill Stewart', 6),
#  ('Adam Brown', 6),
#  ('Alan White', 6),
#  ('Samu', 6),
#  ('Paul Evans', 6),
#  ("James O'Brien", 6),
#  ('George Stevens', 6),
#  ('Sergey Kuznetsov', 6),
#  ('Ferdinand', 6),
#  ('Tom Daly', 6),
#  ('William Jackson', 6),
#  ('George Moore', 6),
#  ('Andrew Johnson', 6),
#  ('Peter Johnson', 6),
#  ('Phil Jones', 6),
#  ('Roger Williams', 6),
#  ('James Williams', 6),
#  ('Charlie Williams', 6),
#  ('Arthur Wood', 6),
#  ('Danny Green', 6),
#  ('Chris Harris', 6),
#  ('Magnus', 6),
#  ('Frederick III', 6),
#  ('Joseph Johnson', 6),
#  ('John McDermott', 6),
#  ('George McLeod', 6),
#  ('Tom Wright', 6),
#  ('Ali Raza', 6),
#  ('Rodri', 6),
#  ('The Spartan', 6),
#  ('James Ferguson', 6),
#  ('Ian Scott', 6),
#  ('Tom Walsh', 6),
#  ('Lee Evans', 6),
#  ('George Burns', 6),
#  ('William Henry', 6),
#  ('Otto I', 6),
#  ('Wang Yang', 6),
#  ('Chris Murphy', 6),
#  ('David Hale', 6),
#  ('David Richards', 6),
#  ('Charlie Jones', 6),
#  ('Simon Williams', 6),
#  ('Paul Rogers', 6),
#  ('John Lucas', 6),
#  ('Alan Jones', 6),
#  ('James McDonald', 6),
#  ('Pat Kelly', 6),
#  ('William Bradford', 6),
#  ('Paul Davies', 6),
#  ('Tom Taylor', 6),
#  ('Bill Ward', 6),
#  ('Richard Wallace', 6),
#  ('Henry Wilson', 6),
#  ('William Dunn', 6),
#  ('John Douglas', 6),
#  ('Santos', 6),
#  ('Thomas Harrison', 6),
#  ('Leslie Jones', 6),
#  ('Pawan Kumar', 6),
#  ('Tom Clarke', 6),
#  ('Tom Hamilton', 6),
#  ('George Hunter', 6),
#  ('David Bishop', 6),
#  ('Juanjo', 6),
#  ('Keith Williams', 6),
#  ('Ray Price', 6),
#  ('Thomas Zacharias', 6),
#  ('Paul Campbell', 6),
#  ('John Perry', 6),
#  ('Paul Edwards', 6),
#  ('Neil Young', 6),
#  ('Tom Ryan', 6),
#  ('George Gray', 6),
#  ('Richard Bennett', 6),
#  ('John Lindsay', 6),
#  ('Kevin Martin', 6),
#  ('Eleanor', 6),
#  ('Tom Parker', 6),
#  ('Ron Wilson', 6),
#  ('Rodrigo', 6),
#  ('George Davies', 6),
#  ('Richard Hamilton', 6),
#  ('Kevin Anderson', 6),
#  ('James Gray', 6),
#  ('Peter Bradley', 6),
#  ('Thomas Howard', 6),
#  ('William Reid', 6),
#  ('Ben Wright', 6),
#  ('Prince Albert', 6),
#  ('Jim Thompson', 6),
#  ('George Wood', 6),
#  ('James Scott', 6),
#  ('The Machine', 6),
#  ('John Gordon', 6),
#  ('Paul Walker', 6),
#  ('Joanna', 6),
#  ('Andrew Taylor', 6),
#  ('James Stuart', 6),
#  ('Brian Turner', 6),
#  ('Les Smith', 6),
#  ('Jack Johnson', 6),
#  ('Peter Walker', 6),
#  ('Chris Martin', 6),
#  ('The Marquess of Aberdeen and Temair', 6),
#  ('Neto', 6),
#  ('Michael Gallagher', 6),
#  ('Mike Ryan', 6),
#  ('Ian Gibson', 6),
#  ('Mike Murphy', 6),
#  ('Michael Lee', 6),
#  ('James Ross', 6),
#  ('John Abbott', 6),
#  ('Zoran Zlatkovski', 6),
#  ('Joseph Jackson', 6),
#  ('Ron James', 6),
#  ('David Burns', 6),
#  ('Moreno', 6),
#  ('The Earl Spencer', 6),
#  ('George Fox', 6),
#  ('Tom Scott', 6),
#  ('Miguel', 6),
#  ('William Phillips', 6),
#  ('Bill Robinson', 6),
#  ('Tom Lynch', 6),
#  ('Jim Taylor', 6),
#  ...]

# %%
print(len(set(non_person_names)))
Counter(non_person_names).most_common()
# Out:
# 1189451
# [('Pennsylvania', 634),
#  ("''", 319),
#  ('Greatest Hits', 317),
#  ('Aliabad', 246),
#  ('Hoseynabad', 199),
#  ('Grand National', 174),
#  ('Hasanabad', 161),
#  ('Hajjiabad', 157),
#  ('Mohammadabad', 150),
#  ('Buddleja davidii', 144),
#  ('Kentucky Derby', 139),
#  ('Live', 132),
#  ('Abbasabad', 127),
#  ('Ahmadabad', 125),
#  ('Eslamabad', 120),
#  ('Pilot', 118),
#  ('First Presbyterian Church', 114),
#  ('Zalesie', 107),
#  ('Kheyrabad', 104),
#  ('Amirabad', 101),
#  ('Jafarabad', 100),
#  ('Home', 100),
#  ('Dowlatabad', 100),
#  ('Mahmudabad', 92),
#  ('Magyar Kupa', 89),
#  ('Buddleja hybrid', 87),
#  ('Chatham Cup', 85),
#  ('Mehdiabad', 82),
#  ('First Baptist Church', 82),
#  ('Karimabad', 80),
#  ('U.S. Post Office', 78),
#  ('Washington Township', 77),
#  ('Copa del Rey', 77),
#  ('Jackson Township', 76),
#  ('Akbarabad', 73),
#  ('Ebrahimabad', 73),
#  ('Valea Mare River', 72),
#  ('Victoria', 70),
#  ('Heydarabad', 70),
#  ('Shamsabad', 70),
#  ('Union Township', 68),
#  ('Fathabad', 68),
#  ('Gold', 68),
#  ('Qasemabad', 66),
#  ('DFB-Pokal', 65),
#  ('Albanian Cup', 64),
#  ('Israel State Cup', 64),
#  ('Torneo Mondiale di Calcio Coppa Carnevale', 60),
#  ('Bulgarian Cup', 60),
#  ('Masonic Temple', 56),
#  ("NCAA Division I Men's Soccer Championship", 55),
#  ('The Preakness Stakes', 55),
#  ('Paradise', 54),
#  ('Shine', 54),
#  ('Love', 53),
#  ('Christ Church', 53),
#  ('The Collection', 52),
#  ('FA Trophy', 52),
#  ('Phoenix', 51),
#  ('Ulmus parvifolia', 51),
#  ('Trinity Episcopal Church', 51),
#  ('Borki', 51),
#  ('Ulmus americana', 51),
#  ('Deh Now', 50),
#  ('Rahmatabad', 50),
#  ('Angel', 49),
#  ('National Assembly', 49),
#  ('Kamionka', 49),
#  ('Ruda', 49),
#  ('Aminabad', 49),
#  ('Algerian Cup', 49),
#  ('Forever', 48),
#  ('Liberty Township', 48),
#  ('Free', 48),
#  ("St Mary's Church", 48),
#  ('Firuzabad', 48),
#  ('The Ultimate Collection', 48),
#  ('Piaski', 47),
#  ('Main Street Historic District', 47),
#  ("St. John's Episcopal Church", 47),
#  ('Feyzabad', 47),
#  ('Seyyedabad', 47),
#  ('Life', 46),
#  ('One', 45),
#  ('Freedom', 45),
#  ('Together', 45),
#  ('Soltanabad', 45),
#  ('Jefferson Township', 45),
#  ('Nurabad', 45),
#  ('Ulmus', 45),
#  ('Laurence Olivier Award', 45),
#  ('Anthology', 45),
#  ('Malekabad', 44),
#  ('Esmailabad', 44),
#  ('Center Township', 43),
#  ('Hero', 43),
#  ('Smile', 43),
#  ('Resurrection', 43),
#  ('Jalalabad', 43),
#  ('Nasirabad', 43),
#  ('Irish Cup', 43),
#  ('Rahimabad', 43),
#  ('Wygoda', 43),
#  ('Sacred Heart Cathedral', 42),
#  ('Time', 42),
#  ('Sharifabad', 42),
#  ("NCAA Men's Water Polo Championship", 42),
#  ('Hemmatabad', 41),
#  ('Janowo', 41),
#  ('Podlesie', 41),
#  ('Ulmus minor', 41),
#  ('Inside Out', 41),
#  ('Alive', 41),
#  ("St. Paul's Episcopal Church", 41),
#  ('Yusefabad', 41),
#  ("NCAA Men's Volleyball Tournament", 41),
#  ('Love Songs', 40),
#  ('Santa Cruz', 40),
#  ('Belmont', 40),
#  ('Hope', 40),
#  ('Zawady', 40),
#  ("St. Mary's Church", 40),
#  ('Asadabad', 40),
#  ('Azizabad', 40),
#  ('Borek', 40),
#  ('Zawada', 40),
#  ('First Congregational Church', 40),
#  ('Murphy Lake', 40),
#  ('International Airport', 39),
#  ('Svenska Cupen', 39),
#  ('Rezaabad', 39),
#  ('Church of St Mary', 39),
#  ('Ulmus hybrid cultivar', 39),
#  ('Aurora', 38),
#  ('Nosratabad', 38),
#  ('Blue', 38),
#  ('Nowiny', 38),
#  ('Holy Trinity Church', 38),
#  ('Friends', 38),
#  ('Mirabad', 38),
#  ('Nasrabad', 38),
#  ('Khorramabad', 38),
#  ('CECAFA Cup', 37),
#  ('Wynyard', 37),
#  ('Howmeh Rural District', 37),
#  ('Mehrabad', 37),
#  ('Nordland', 37),
#  ('Frauen DFB-Pokal', 37),
#  ('Yugoslav Cup', 37),
#  ('First United Methodist Church', 37),
#  ('Beth Israel', 37),
#  ('Cypriot Cup', 37),
#  ('Valiabad', 37),
#  ('Magic', 36),
#  ('Moradabad', 36),
#  ('European Cup', 36),
#  ('Heaven', 36),
#  ('Monster', 36),
#  ('Grace Episcopal Church', 36),
#  ('Baqerabad', 36),
#  ('Najafabad', 36),
#  ('Saidabad', 36),
#  ('Heartbeat', 36),
#  ('Taqiabad', 36),
#  ('Brzeziny', 36),
#  ('Richmond', 35),
#  ('Revolution', 35),
#  ('Sunshine', 35),
#  ('Hojjatabad', 35),
#  ('Evolution', 35),
#  ('All Saints Church', 35),
#  ('Trouble', 35),
#  ('Boomerang', 35),
#  ("People's Republic of Bangladesh", 35),
#  ('Rise', 35),
#  ('Sadeqabad', 35),
#  ('Ulmus glabra', 35),
#  ('NCAA Division I Field Hockey Championship', 35),
#  ('Tazehabad', 35),
#  ('Gaj', 34),
#  ('Rain', 34),
#  ('Reflections', 34),
#  ('Huta', 34),
#  ('Harrison Township', 34),
#  ('U.S. Post Office and Courthouse', 34),
#  ('Stay', 34),
#  ('Riverside', 34),
#  ('Clifton', 34),
#  ('San Antonio', 33),
#  ('Slatina', 33),
#  ('Empire', 33),
#  ('Black River', 33),
#  ('America', 33),
#  ('Believe', 33),
#  ('Roller Hockey World Cup', 33),
#  ('Tony Awardfor', 33),
#  ('Biskupice', 33),
#  ('Northumberland', 33),
#  ('Kazemabad', 33),
#  ('Franklin Township', 33),
#  ('Lincoln Township', 33),
#  ("NCAA Women's Soccer Tournament", 33),
#  ('GNOME', 32),
#  ('San Francisco', 32),
#  ('I Love You', 32),
#  ('Changes', 32),
#  ('Hesar', 32),
#  ('Beautiful', 32),
#  ('Closer', 32),
#  ('Lincoln', 32),
#  ('Solo', 32),
#  ('Stanley', 32),
#  ('Valea Rea River', 32),
#  ('You', 32),
#  ('Fire', 32),
#  ('Allahabad', 32),
#  ('Salehabad', 32),
#  ('Richland Township', 32),
#  ('African Cup of Champions Clubs', 32),
#  ('Wellington', 31),
#  ('Eden', 31),
#  ('Ministry of Finance', 31),
#  ('Newtown', 31),
#  ('Destiny', 31),
#  ('New York', 31),
#  ('Mother', 31),
#  ('Waterloo', 31),
#  ('The Other Side', 31),
#  ('Central High School', 31),
#  ('Kingston', 31),
#  ('Fakhrabad', 31),
#  ('Mansurabad', 31),
#  ('Washington County', 31),
#  ('Hold On', 31),
#  ('Grant Township', 31),
#  ('UEFA Cup', 31),
#  ('California', 30),
#  ('Ministry of Foreign Affairs', 30),
#  ('Full Circle', 30),
#  ('Mount Pleasant', 30),
#  ('Wonderland', 30),
#  ('Icon', 30),
#  ('Woodside', 30),
#  ('The Gift', 30),
#  ('Springfield', 30),
#  ('Untitled', 30),
#  ('Sunnyside', 30),
#  ('Christ Episcopal Church', 30),
#  ('Chenar', 30),
#  ('Jahanabad', 30),
#  ('Sacred Heart Church', 30),
#  ('Star Awardsfor', 30),
#  ('San Miguel', 29),
#  ('II', 29),
#  ('Runaway', 29),
#  ('Now Deh', 29),
#  ('Salem', 29),
#  ('Red', 29),
#  ('Tonight', 29),
#  ('Little River', 29),
#  ('Gloucester', 29),
#  ('Gravity', 29),
#  ('Christmas', 29),
#  ('Copa do Brasil', 29),
#  ("African Cup Winners' Cup", 29),
#  ('Osiek', 28),
#  ('Crush', 28),
#  ('Everything', 28),
#  ('Play', 28),
#  ('Pure', 28),
#  ('Anthrenocerus', 28),
#  ('Union Station', 28),
#  ('Grace', 28),
#  ('Hamilton', 28),
#  ('X', 28),
#  ('Survivor', 28),
#  ('Bielawy', 28),
#  ('Lipa', 28),
#  ('Lipiny', 28),
#  ('Twilight', 28),
#  ('Government House', 28),
#  ('The One', 28),
#  ('Face to Face', 28),
#  ('San Juan', 28),
#  ('The Definitive Collection', 28),
#  ('v.', 28),
#  ('Qaderabad', 28),
#  ('The Promise', 28),
#  ('Breathe', 28),
#  ('Uganda Cup', 28),
#  ('Dreams', 28),
#  ('Scottish Cup', 28),
#  ('Hello', 27),
#  ('Coming Home', 27),
#  ('Change', 27),
#  ('Miracle', 27),
#  ('Independence Day', 27),
#  ('Stronger', 27),
#  ('Reunion', 27),
#  ('Broadway', 27),
#  ('Crazy', 27),
#  ('Grabowiec', 27),
#  ('The Game', 27),
#  ('Infinity', 27),
#  ('Eclipse', 27),
#  ('Love Story', 27),
#  ("St. John's Church", 27),
#  ('Milton', 27),
#  ('Hollywood', 27),
#  ('Wanted', 27),
#  ('Crown Prince Cup', 27),
#  ('Homecoming', 27),
#  ('Baby', 27),
#  ('Tazeh Kand', 27),
#  ('Irish League Cup', 27),
#  ('Passion', 27),
#  ('South Sudan', 27),
#  ('Siedliska', 27),
#  ('Santa Rosa', 26),
#  ('Virginia', 26),
#  ('Blackout', 26),
#  ('Ghost', 26),
#  ('Happiness', 26),
#  ('Republic of Indonesia', 26),
#  ('UEFA Champions League', 26),
#  ('Bellevue', 26),
#  ('Go', 26),
#  ('Middleton', 26),
#  ('Surrender', 26),
#  ('Croatian Football Cup', 26),
#  ('Goodbye', 26),
#  ('Alone', 26),
#  ('Armenian Cup', 26),
#  ('United States', 26),
#  ('Saadatabad', 26),
#  ('Grabowo', 26),
#  ('Slovenian Football Cup', 26),
#  ("St. Paul's Church", 26),
#  ('After Hours', 26),
#  ('Victory', 26),
#  ('Newport', 25),
#  ('Chinatown', 25),
#  ('Always', 25),
#  ('Sanctuary', 25),
#  ('Karma', 25),
#  ("St. Peter's Church", 25),
#  ('Live in London', 25),
#  ('Darband', 25),
#  ('MTV Unplugged', 25),
#  ('Franklin County', 25),
#  ('Redemption', 25),
#  ('Columbia', 25),
#  ('Jefferson County', 25),
#  ('The Journey', 25),
#  ('Silver Lake', 25),
#  ('San Isidro', 25),
#  ('Today', 25),
#  ('Tomorrow', 25),
#  ('Laski', 25),
#  ('Marysin', 25),
#  ("St. Mark's Episcopal Church", 25),
#  ('Santiago', 25),
#  ('Joy', 25),
#  ('----', 25),
#  ('Legacy', 25),
#  ('Weston', 25),
#  ('Santa Fe', 25),
#  ('Disney Channel', 25),
#  ('Utopia', 25),
#  ('Fairview', 25),
#  ('Run', 25),
#  ('Wings', 25),
#  ('Preston', 25),
#  ('Belgian Cup', 25),
#  ('Genesis', 25),
#  ('Khosrowabad', 25),
#  ('Rainbow', 25),
#  ('Seyfabad', 25),
#  ('Blood', 25),
#  ('Fearless', 25),
#  ('Rostamabad', 25),
#  ('The Greatest Hits', 25),
#  ('Scream', 25),
#  ('Wolica', 25),
#  ('All-Ireland Senior B Hurling Championship', 25),
#  ('Wayne Township', 25),
#  ('Qeshlaq', 25),
#  ('Novo Selo', 24),
#  ('Santo Domingo', 24),
#  ('Burn', 24),
#  ('Atlas', 24),
#  ('Arena', 24),
#  ('Sugar', 24),
#  ('Champion', 24),
#  ('She', 24),
#  ('Jackson County', 24),
#  ('Paris', 24),
#  ('Alice', 24),
#  ('Live in Japan', 24),
#  ('The Three Musketeers', 24),
#  ('Abdolabad', 24),
#  ('Sunrise', 24),
#  ('San Fernando', 24),
#  ('Arcadia', 24),
#  ('I Am', 24),
#  ('Troms', 24),
#  ('Yana Urqu', 24),
#  ('Holiday', 24),
#  ('Guadalupe', 24),
#  ('Czech Cup', 24),
#  ('Fairfield', 24),
#  ('Notre Dame High School', 24),
#  ('Bahramabad', 24),
#  ('Let It Go', 24),
#  ('Jannatabad', 24),
#  ('Khalilabad', 24),
#  ('Naserabad', 24),
#  ('The Singles', 24),
#  ('Hong Kong FA Cup', 24),
#  ('Commonwealth of Independent States Cup', 24),
#  ('Drive', 24),
#  ('Jamalabad', 24),
#  ('Zamanabad', 24),
#  ('Bliss', 24),
#  ('Lincoln County', 24),
#  ('St. James Episcopal Church', 24),
#  ('Good Times', 23),
#  ('FIFA World Cup', 23),
#  ('Derby', 23),
#  ('High School', 23),
#  ('V', 23),
#  ('The Platinum Collection', 23),
#  ('First Love', 23),
#  ('Coppa Italia', 23),
#  ('Thank You', 23),
#  ('Sogn og Fjordane', 23),
#  ('Escape', 23),
#  ('Florida', 23),
#  ('Liberty', 23),
#  ('Newton', 23),
#  ('Mitchell', 23),
#  ('Now', 23),
#  ('Lost', 23),
#  ('Timeless', 23),
#  ('Cinderella', 23),
#  ('African Cup of Nations', 23),
#  ('Unbreakable', 23),
#  ('In Concert', 23),
#  ('Happy', 23),
#  ('The River', 23),
#  ('FAI Cup', 23),
#  ('Superman', 23),
#  ('Candy', 23),
#  ('Zakrzewo', 23),
#  ('Woodstock', 23),
#  ('Elmwood', 23),
#  ('Up All Night', 23),
#  ('Hashemabad', 23),
#  ('Kamalabad', 23),
#  ('Qaleh Now', 23),
#  ('Secrets', 23),
#  ('Without You', 23),
#  ("St Peter's Church", 23),
#  ('Ride', 23),
#  ('Encore', 23),
#  ('Logan Township', 23),
#  ('Dastjerd', 23),
#  ('Sadabad', 23),
#  ('King', 22),
#  ('Oppland', 22),
#  ('Dobra', 22),
#  ('San Carlos', 22),
#  ('San Luis', 22),
#  ('Windsor', 22),
#  ('Greenwood', 22),
#  ('Honey', 22),
#  ('Central', 22),
#  ('This Time', 22),
#  ('Invincible', 22),
#  ('West End', 22),
#  ('Monroe Township', 22),
#  ('Heroes', 22),
#  ('Yahyaabad', 22),
#  ('Fox', 22),
#  ('Trinity', 22),
#  ('Alice in Wonderland', 22),
#  ('Crossroads', 22),
#  ('Human', 22),
#  ('Rush', 22),
#  ('Nickelodeon', 22),
#  ('Lipie', 22),
#  ('Dangerous', 22),
#  ('Hurricane', 22),
#  ('Super Hits', 22),
#  ('The Real Thing', 22),
#  ('Contact', 22),
#  ('Underground', 22),
#  ('My Love', 22),
#  ('Echo', 22),
#  ('Nezamabad', 22),
#  ('Inferno', 22),
#  ('Elizabeth', 22),
#  ('Ukrainian Cup', 22),
#  ('Out of the Blue', 22),
#  ('Revenge', 22),
#  ('Imagination', 22),
#  ('Shadows', 22),
#  ('Liberty High School', 22),
#  ("St. Mary's Catholic Church", 22),
#  ('Aberdeen', 22),
#  ('Lincoln High School', 22),
#  ('Sirens', 22),
#  ('Abdollahabad', 22),
#  ('Golestan', 22),
#  ('Osiny', 22),
#  ('Cartoon Network', 22),
#  ('Once Upon a Time', 22),
#  ('III', 22),
#  ('Pukara', 22),
#  ('Piotrowice', 22),
#  ("CONCACAF Champions' Cup", 22),
#  ('Bukowiec', 22),
#  ('Luna', 21),
#  ('Main Street', 21),
#  ('Carmen', 21),
#  ("It's About Time", 21),
#  ('My Way', 21),
#  ('Majdan', 21),
#  ('Marion Township', 21),
#  ('AFC Youth Championship', 21),
#  ('Only You', 21),
#  ('Mobarakabad', 21),
#  ('Korean FA Cup', 21),
#  ('Musaabad', 21),
#  ('Huilong', 21),
#  ('The Stranger', 21),
#  ('Marion County', 21),
#  ('Black', 21),
#  ('La Paz', 21),
#  ('Avalon', 21),
#  ('Asian Club Championship', 21),
#  ('Senate', 21),
#  ('The Early Years', 21),
#  ('Janowice', 21),
#  ('Desire', 21),
#  ('Marianka', 21),
#  ('The Truth', 21),
#  ('Hamlet', 21),
#  ('Manchester', 21),
#  ('Winter', 21),
#  ('Superstar', 21),
#  ('Voices', 21),
#  ('Gone', 21),
#  ('University of Santo Tomas', 21),
#  ('Sutton', 21),
#  ('Hopewell', 21),
#  ('Linden', 21),
#  ('Broken', 21),
#  ('Georgia', 21),
#  ('Dehnow', 21),
#  ('Mohsenabad', 21),
#  ('Someday', 21),
#  ('Dawn', 21),
#  ('San Lorenzo', 21),
#  ('Yengejeh', 21),
#  ('Restless', 21),
#  ('Slovak Cup', 21),
#  ('CMLL Super Viernes', 21),
#  ('Wysoka', 21),
#  ('Greatest Hits Live', 21),
#  ('Psary', 20),
#  ('Darling', 20),
#  ('Independence', 20),
#  ('Nemesis', 20),
#  ('Franklin', 20),
#  ('Move', 20),
#  ('Real', 20),
#  ('Rosedale', 20),
#  ('Gloria', 20),
#  ('Collection', 20),
#  ('Save Me', 20),
#  ('Temptation', 20),
#  ('Ruby', 20),
#  ('Trinity Church', 20),
#  ('Metro', 20),
#  ('Requiem', 20),
#  ('Orange', 20),
#  ('Crash', 20),
#  ('Lost and Found', 20),
#  ('Silence', 20),
#  ('Cleopatra', 20),
#  ('The Bridge', 20),
#  ('House of Representatives', 20),
#  ('Truth', 20),
#  ('Madison County', 20),
#  ('The Awakening', 20),
#  ('Pride', 20),
#  ('Spirit', 20),
#  ('Touch', 20),
#  ('After Dark', 20),
#  ('Unknown', 20),
#  ('The Messenger', 20),
#  ('Why', 20),
#  ('Prairie Township', 20),
#  ('Hucisko', 20),
#  ('Kent', 20),
#  ('Konary', 20),
#  ('Kamenica', 20),
#  ('Jealousy', 20),
#  ('Lucky', 20),
#  ('Hunter', 20),
#  ('Beauty and the Beast', 20),
#  ('High-Speed Railway', 20),
#  ('Don', 20),
#  ('Miami', 20),
#  ('Douglas', 20),
#  ('Australia', 20),
#  ('Yenice', 20),
#  ('Santa Ana', 20),
#  ('Brzezie', 20),
#  ('Guilty', 20),
#  ('Rudka', 20),
#  ('Brothers', 20),
#  ('Fever', 20),
#  ('Albion', 20),
#  ('Warrior', 20),
#  ('Cumberland', 20),
#  ('London', 20),
#  ('Revelation', 20),
#  ('Hume', 20),
#  ('Black Mountain', 20),
#  ('Crystal Lake', 20),
#  ('Here I Am', 20),
#  ('Riverview', 20),
#  ("St. Peter's Episcopal Church", 20),
#  ('Woodlands', 20),
#  ('Atlantis', 20),
#  ('Macedonian Football Cup', 20),
#  ('Church of All Saints', 20),
#  ('Kushk', 20),
#  ('Safiabad', 20),
#  ('Canning', 20),
#  ('Hush', 20),
#  ('Grabina', 20),
#  ('Legend', 20),
#  ('Palestine Cup', 20),
#  ('Fantasy', 20),
#  ('Stars', 20),
#  ('Mexico', 20),
#  ('Soul Train Music Awards', 20),
#  ('Taherabad', 20),
#  ('Colours', 20),
#  ('Providence', 20),
#  ('Potok', 20),
#  ('Perry Township', 20),
#  ('Madison Township', 20),
#  ('The Peel Sessions', 20),
#  ('Asylum', 20),
#  ('Summit Lake', 20),
#  ('South American Championship', 20),
#  ('Rudniki', 20),
#  ("C-USA Men's Soccer Tournament", 20),
#  ('Clay Township', 20),
#  ('Carnegie Library', 20),
#  ('Upton', 19),
#  ('Butterfly', 19),
#  ('Milan', 19),
#  ('Caledonia', 19),
#  ('Newcastle', 19),
#  ('Celebration', 19),
#  ('I Want You', 19),
#  ('Ministry of Justice', 19),
#  ('My Life', 19),
#  ('Chester', 19),
#  ('The Message', 19),
#  ('Money', 19),
#  ('Spain', 19),
#  ('Singles', 19),
#  ('I Do', 19),
#  ('City Hall', 19),
#  ('Chelsea', 19),
#  ('Socialist Republic of Vietnam', 19),
#  ('Skin', 19),
#  ('Star', 19),
#  ('thumb', 19),
#  ('Hamidabad', 19),
#  ('Qarah Bolagh', 19),
#  ('Kiss', 19),
#  ('Avalanche', 19),
#  ('Faith', 19),
#  ('Again', 19),
#  ('Downtown', 19),
#  ('Union', 19),
#  ('Football Club', 19),
#  ('Dracula', 19),
#  ('Budy', 19),
#  ('Grodzisko', 19),
#  ('Kamieniec', 19),
#  ('Karolewo', 19),
#  ('Boston', 19),
#  ('Oakland', 19),
#  ('Norwegian Football Cup', 19),
#  ('Justice', 19),
#  ('Mirage', 19),
#  ("Don't Look Back", 19),
#  ('The Voice', 19),
#  ('Family', 19),
#  ('Mercy', 19),
#  ('Oasis', 19),
#  ('Trust', 19),
#  ('Exodus', 19),
#  ('Esperanza', 19),
#  ('Sacrifice', 19),
#  ('Spellbound', 19),
#  ('Alma', 19),
#  ('Mary', 19),
#  ('Pioneer', 19),
#  ('White River', 19),
#  ('John F. Kennedy High School', 19),
#  ('Neptune', 19),
#  ('Whitehall', 19),
#  ('Jericho', 19),
#  ('Woodlawn', 19),
#  ('Hazfi Cup', 19),
#  ('Remember Me', 19),
#  ('Venus', 19),
#  ('Metropolis', 19),
#  ('Hampton', 19),
#  ('Ministry of Education', 19),
#  ('Qaleh Juq', 19),
#  ('Rose Hill', 19),
#  ('Midnight', 19),
#  ('Macbeth', 19),
#  ('Still', 19),
#  ('Enterprise', 19),
#  ('NFL playoffs', 19),
#  ('Haunted', 19),
#  ('Treasure Island', 19),
#  ('Obsession', 19),
#  ('Revelations', 19),
#  ('Double Trouble', 19),
#  ('Georgetown', 19),
#  ('Three', 19),
#  ('One Love', 19),
#  ('Zarzecze', 19),
#  ('Bugaj', 19),
#  ('Anielin', 19),
#  ('First Christian Church', 19),
#  ('Flower', 18),
#  ('Bullet', 18),
#  ('Hastings', 18),
#  ('You and Me', 18),
#  ('Circus', 18),
#  ('More', 18),
#  ('I Believe', 18),
#  ('Out of Control', 18),
#  ('Heart', 18),
#  ('Anna', 18),
#  ('Switch', 18),
#  ('Wake Up', 18),
#  ('Clay County', 18),
#  ('Amnesia', 18),
#  ('Comet', 18),
#  ('I', 18),
#  ("Let's Dance", 18),
#  ('Heat', 18),
#  ('Storm', 18),
#  ('The End', 18),
#  ('Adamowo', 18),
#  ('Brave', 18),
#  ('Jankowice', 18),
#  ('Komorowo', 18),
#  ('Holy Cross Church', 18),
#  ('Olszanka', 18),
#  ('Eternity', 18),
#  ('Inside', 18),
#  ('Arab Club Champions Cup', 18),
#  ('Eureka', 18),
#  ('Egypt', 18),
#  ('Bare', 18),
#  ('Dust', 18),
#  ('Countdown', 18),
#  ('Betrayal', 18),
#  ('Lamar Hunt U.S. Open Cup', 18),
#  ('Chicago', 18),
#  ('Iris', 18),
#  ('Still Life', 18),
#  ('Wila Qullu', 18),
#  ('Heartland', 18),
#  ('The Good Life', 18),
#  ('Cry', 18),
#  ('Two', 18),
#  ('Yanaqucha', 18),
#  ('Stella', 18),
#  ('Supernova', 18),
#  ('Saturday Night', 18),
#  ('Jordan', 18),
#  ('Cedar Grove', 18),
#  ('Mill Creek', 18),
#  ('Girlfriend', 18),
#  ('Brody', 18),
#  ('Ghosts', 18),
#  ('Romance', 18),
#  ('Evergreen', 18),
#  ('First National Bank Building', 18),
#  ('Gola', 18),
#  ('Halloween', 18),
#  ('Amazing', 18),
#  ('Church of St Mary the Virgin', 18),
#  ('Carnival', 18),
#  ('Anything Goes', 18),
#  ('Maya', 18),
#  ('Bistrica', 18),
#  ('Fly', 18),
#  ('First National Bank', 18),
#  ("St. Andrew's Church", 18),
#  ('Perfect', 18),
#  ('Durham', 18),
#  ('The Hits', 18),
#  ('Revival', 18),
#  ('Rudnik', 18),
#  ('Naked', 18),
#  ('Polytechnic University of the Philippines', 18),
#  ('Titan', 18),
#  ('Aftermath', 18),
#  ('NSL Cup', 18),
#  ('Metropolitan City of Naples', 18),
#  ('Zielonka', 18),
#  ('Harmony', 18),
#  ('Urana', 18),
#  ('Eshqabad', 18),
#  ('South American Youth Championship', 18),
#  ('Pike County', 18),
#  ('Cegielnia', 18),
#  ('Ab Barik', 18),
#  ('Berg', 17),
#  ('Flashback', 17),
#  ('Panorama', 17),
#  ('Lipnica', 17),
#  ('Vengeance', 17),
#  ('Cheshmeh Kabud', 17),
#  ('The Return', 17),
#  ('All or Nothing', 17),
#  ('Hercules', 17),
#  ('Venezuela', 17),
#  ('A Christmas Carol', 17),
#  ('Beaumont', 17),
#  ('Teenage Mutant Ninja Turtles', 17),
#  ('Texas', 17),
#  ('The Beginning', 17),
#  ('Beaufort', 17),
#  ('Dream', 17),
#  ('Nazarabad', 17),
#  ('Orion', 17),
#  ('Airport', 17),
#  ('Mars', 17),
#  ('Cerro Gordo County', 17),
#  ('Innocence', 17),
#  ('Poison', 17),
#  ('Next', 17),
#  ('Lights Out', 17),
#  ('Wish You Were Here', 17),
#  ('San Pablo', 17),
#  ('Faces', 17),
#  ('Mornington', 17),
#  ('Ministry of Defence', 17),
#  ('Monroe County', 17),
#  ('Union County', 17),
#  ('Kaleidoscope', 17),
#  ('Immaculate Conception Cathedral', 17),
#  ('Power', 17),
#  ('Lipnik', 17),
#  ('Marianowo', 17),
#  ('Mokre', 17),
#  ('Malta', 17),
#  ('The Outsider', 17),
#  ('Westwood', 17),
#  ('Green Lake', 17),
#  ('Azerbaijan Cup', 17),
#  ('Brighton', 17),
#  ('Shelter', 17),
#  ('The Gathering', 17),
#  ('Kensington', 17),
#  ('Turn It Up', 17),
#  ('Happy Valley', 17),
#  ('Tango', 17),
#  ('Beast', 17),
#  ('Memorial Stadium', 17),
#  ('Suomen Cup', 17),
#  ('Journey', 17),
#  ('State of New Jersey', 17),
#  ('Amsterdam', 17),
#  ('Ministry of Health', 17),
#  ('Up', 17),
#  ('Vernon', 17),
#  ('Midway', 17),
#  ('Girls', 17),
#  ('Thornhill', 17),
#  ('Wakool', 17),
#  ('The Chase', 17),
#  ('The Star', 17),
#  ('Girl', 17),
#  ('Stranded', 17),
#  ('Labyrinth', 17),
#  ('Masterpiece', 17),
#  ('Carlton', 17),
#  ('Haft Cheshmeh', 17),
#  ('Majidabad', 17),
#  ('Qarah Tappeh', 17),
#  ('Vendetta', 17),
#  ('Automatic', 17),
#  ('Around the World', 17),
#  ('Lullaby', 17),
#  ('Lipno', 17),
#  ('Ashley', 17),
#  ('Right Now', 17),
#  ('Breakdown', 17),
#  ('The Hunter', 17),
#  ('Sang-e Sefid', 17),
#  ('Tavakkolabad', 17),
#  ('African Youth Championship', 17),
#  ('Echoes', 17),
#  ('Ultimate Collection', 17),
#  ('Rogowo', 17),
#  ('Unity', 17),
#  ("European Cup Winners' Cup", 17),
#  ('All Night Long', 17),
#  ('Pulse', 17),
#  ('Montgomery County', 17),
#  ('Piaseczno', 17),
#  ('Zacisze', 17),
#  ('Borowiec', 17),
#  ('First Methodist Episcopal Church', 17),
#  ('Reckless', 16),
#  ('Buena Vista', 16),
#  ('Gordon', 16),
#  ('Atlanta', 16),
#  ("'''", 16),
#  ('Rosario', 16),
#  ('Breakaway', 16),
#  ('Green', 16),
#  ('Maria', 16),
#  ('Somerset', 16),
#  ('Kahriz', 16),
#  ('Suddenly', 16),
#  ('Alexander', 16),
#  ('Higher', 16),
#  ('I Need You', 16),
#  ('Jack', 16),
#  ('Mama', 16),
#  ('One in a Million', 16),
#  ('Relentless', 16),
#  ('UEFA Futsal Cup', 16),
#  ('Style', 16),
#  ('Nova', 16),
#  ('Speed', 16),
#  ('Casanova', 16),
#  ('Roma', 16),
#  ('Rogaland', 16),
#  ('Seven', 16),
#  ('Real Life', 16),
#  ('Stand Up', 16),
#  ('Down to Earth', 16),
#  ('Awake', 16),
#  ('Welcome', 16),
#  ('High Society', 16),
#  ('Blackwater', 16),
#  ('Delta', 16),
#  ('Hordaland', 16),
#  ('One More Time', 16),
#  ('Cosmos', 16),
#  ('Wayne County', 16),
#  ('Lebanon', 16),
#  ('Walton', 16),
#  ('Daddy', 16),
#  ('Diana', 16),
#  ('Ramnagar', 16),
#  ('Julia', 16),
#  ('Murray', 16),
#  ('The Letter', 16),
#  ('Batman', 16),
#  ('History', 16),
#  ('Jeziorki', 16),
#  ('Kamienica', 16),
#  ('Long Island', 16),
#  ('Martin', 16),
#  ('Deadline', 16),
#  ('Hillside', 16),
#  ('Scott Township', 16),
#  ('Virus', 16),
#  ('The Circle', 16),
#  ('The City', 16),
#  ('Berlin', 16),
#  ('Tara', 16),
#  ('Bad Company', 16),
#  ('The Family', 16),
#  ('Nelson', 16),
#  ('Vertigo', 16),
#  ('Estonian Cup', 16),
#  ("St. Mary's Cathedral", 16),
#  ...]

# %%
def write_txt(file, arr):
    for string in arr:
        file.write(string+'\n')
    print('file saved')

# %%
file_person_names = open('persons.txt', 'w', encoding='utf-8')
file_other_names = open('entities.txt','w', encoding='utf-8')

write_txt(file_person_names, person_names)
write_txt(file_other_names, non_person_names)

file_person_names.close()
file_other_names.close()
# Out:
# file saved
# file saved

# %%
with open('persons.txt', 'r', encoding='utf-8') as f:
    array_per = f.read().split('\n')
